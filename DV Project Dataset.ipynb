# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the dataset
df = pd.read_excel(r"C:\Users\Yap Hui Qing\Documents\number of deaths by risk factor.xlsx")
df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                               3169
# 1                                               3222
# 2                                               3395
# 3                                               3623
# 4                                               3788
#
#    Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 0                                              25633
# 1                                              25872
# 2                                              26309
# 3                                              26961
# 4                                              27658
#
# ...

# %%
# DataFrame
df1 = pd.DataFrame(df)
print(df1)
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                                  3169
# 1                                                  3222
# 2                                                  3395
# 3                                                  3623
# 4                                                  3788
# ...                                                 ...
# 6835                                               2835
# 6836                                               2781
# ...

# %%
# The total number of missing values in each column
df1.isna().sum()
# Out:
# Entity                                                                                                                0
# Code                                                                                                                690
# Year                                                                                                                  0
# Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)                  0
# Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)                  0
# Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)                           0
# Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)                      0
# Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)                                   0
# ...

# %%
# Check the percentage of missing value in each column
# High total cholesterol is appoximately 76% missing values and 1 missing value in High total cholesterol
round(df.isnull().sum()/len(df1),4)
# Out:
# Entity                                                                                                              0.0000
# Code                                                                                                                0.1009
# Year                                                                                                                0.0000
# Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)                0.0000
# Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)                0.0000
# Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)                         0.0000
# Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)                    0.0000
# Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)                                 0.0000
# ...
